# %% [markdown]
# #**Data Understanding & Data Preparation**

# %%
import pandas as pd

# %% [markdown]
# Menganalisis faktor-faktor yang memengaruhi kesuksesan box office film anime, langkah pertama yang harus dilakukan adalah mengumpulkan data dari kaggle yang telah saya downloand sebelumnya, yaitu sebagai berikut:

# %%
df = pd.read_csv("/content/drive/MyDrive/AVD MINPRO 1/top_1000_animes.csv")

df
# Out:
#      anime_id                                         anime_name  \
# 0       16498                                    Attack on Titan
# 1      101922                                       Demon Slayer
# 2        1535                                         DEATH NOTE
# 3      113415                                     Jujutsu Kaisen
# 4       21459                                   My Hero Academia
# ..        ...                                                ...
# 995     97663                                    Knights & Magic
# 996    136707                                    Isekai Yakkyoku
# 997    129192  Tensei Kenja no Isekai Life: Daini no Shokugyo...
# 998    127271                           Ryuu to Sobakasu no Hime
# 999    101571                                 Aggressive Retsuko
#
#                                               genres   type  \
# 0                    Action, Drama, Fantasy, Mystery     TV
# 1    Action, Adventure, Drama, Fantasy, Supernatural     TV
# 2     Mystery, Psychological, Supernatural, Thriller     TV
# 3                        Action, Drama, Supernatural     TV
# 4                          Action, Adventure, Comedy     TV
# ..                                               ...    ...
# 995                           Action, Fantasy, Mecha     TV
# 996                                          Fantasy     TV
# 997               Action, Adventure, Comedy, Fantasy     TV
# 998                    Drama, Music, Mystery, Sci-Fi  MOVIE
# 999                     Comedy, Music, Slice of Life    ONA
#
#      number_of_episodes  rating  total_views  production_cost  \
# 0                    25      84       778095           200000
# 1                    26      83       735876           250000
# 2                    37      84       708493           100000
# 3                    24      85       677899           250000
# 4                    13      77       672551           200000
# ..                  ...     ...          ...              ...
# 995                  13      67        52265           150000
# 996                  12      72        52175           250000
# 997                  12      61        52116           300000
# 998                   1      73        52055           300000
# 999                  10      74        52006           200000
#
#      total_box_office
# 0                30.8
# 1               504.5
# 2                30.0
# 3               196.0
# 4                55.0
# ..                ...
# 995              33.0
# 996              35.0
# 997              39.0
# 998              56.0
# 999              23.0
#
# [1000 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   anime_id              1000 non-null   int64
#  1   anime_name            1000 non-null   object
#  2   genres                1000 non-null   object
#  3   type                  1000 non-null   object
#  4   number_of_episodes    1000 non-null   int64
#  5   rating                1000 non-null   int64
#  6   total_views           1000 non-null   int64
#  7   production_cost       1000 non-null   int64
#  8   total_box_office      1000 non-null   float64
#  9   production_cost_jpy   1000 non-null   int64
#  10  total_box_office_jpy  1000 non-null   float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 86.1+ KB

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
#  Setelah data terkumpul, data tersebut perlu dibersihkan dengan membuang data yang tidak lengkap atau tidak valid dengan data cleaning yang merupakan proses menghapus atau memodifikasi data yang tidak lengkap, duplikat, tidak akurat, dan salah format. Data-data tersebut dihapus atau dimodifikasi untuk memastikan data yang sedang diolah adalah data berkualitas agar dapat menghasilkan keputusan yang lebih akurat.

# %% [markdown]
# ###Melihat Missing

# %% [markdown]
# Melakukan pengecekan missing values perkolom dalam bentuk presentase, guna mendukung pengambilan keputusan pada nilai yang kosong

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# anime_id              0.0
# anime_name            0.0
# genres                0.0
# type                  0.0
# number_of_episodes    0.0
# rating                0.0
# total_views           0.0
# production_cost       0.0
# total_box_office      0.0
# dtype: float64

# %%
df.isnull().sum()
# Out:
# anime_id                0
# anime_name              0
# genres                  0
# type                    0
# number_of_episodes      0
# rating                  0
# total_views             0
# production_cost         0
# total_box_office        0
# production_cost_jpy     0
# total_box_office_jpy    0
# dtype: int64

# %%
df.describe()
# Out:
#             anime_id  number_of_episodes       rating    total_views  \
# count    1000.000000         1000.000000  1000.000000    1000.000000
# mean    63084.119000           19.926000    74.667000  136345.578000
# std     54315.227932           57.600941     7.371733  106097.155245
# min         1.000000            1.000000    45.000000   52006.000000
# 25%     14501.500000           12.000000    70.000000   69314.000000
# 50%     21693.000000           12.000000    75.000000   97868.500000
# 75%    110880.000000           13.000000    80.000000  158302.250000
# max    166873.000000         1110.000000    91.000000  778095.000000
#
#        production_cost  total_box_office
# count      1000.000000       1000.000000
# mean     201400.000000         35.375300
# std       68649.492007         40.570578
# min      100000.000000          7.000000
# 25%      150000.000000         20.000000
# 50%      200000.000000         33.000000
# 75%      250000.000000         46.000000
# max      300000.000000       1001.000000

# %% [markdown]
#  **Duplicated Values**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
#  **Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom               Persentase Outliers
# anime_id                            0.0
# number_of_episodes                 41.5
# rating                              0.8
# total_views                         8.4
# production_cost                     0.0
# total_box_office                    0.0

# %%
columns_to_impute = ["production_cost", "total_box_office"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom               Persentase Outliers
# anime_id                            0.0
# number_of_episodes                 41.5
# rating                              0.8
# total_views                         8.4
# production_cost                     0.0
# total_box_office                    0.0

# %% [markdown]
# **Incosistent Value**

# %%
df.describe()
# Out:
#             anime_id  number_of_episodes       rating    total_views  \
# count    1000.000000         1000.000000  1000.000000    1000.000000
# mean    63084.119000           19.926000    74.667000  136345.578000
# std     54315.227932           57.600941     7.371733  106097.155245
# min         1.000000            1.000000    45.000000   52006.000000
# 25%     14501.500000           12.000000    70.000000   69314.000000
# 50%     21693.000000           12.000000    75.000000   97868.500000
# 75%    110880.000000           13.000000    80.000000  158302.250000
# max    166873.000000         1110.000000    91.000000  778095.000000
#
#        production_cost  total_box_office
# count      1000.000000       1000.000000
# mean     201400.000000         35.375300
# std       68649.492007         40.570578
# min      100000.000000          7.000000
# 25%      150000.000000         20.000000
# 50%      200000.000000         33.000000
# 75%      250000.000000         46.000000
# max      300000.000000       1001.000000

# %% [markdown]
# ## **Construct Data**

# %%
df["profit_margin"] = (df["total_box_office"] - df["production_cost"]) / df["production_cost"]
df
# Out:
#      anime_id                                         anime_name  \
# 0       16498                                    Attack on Titan
# 1      101922                                       Demon Slayer
# 2        1535                                         DEATH NOTE
# 3      113415                                     Jujutsu Kaisen
# 4       21459                                   My Hero Academia
# ..        ...                                                ...
# 995     97663                                    Knights & Magic
# 996    136707                                    Isekai Yakkyoku
# 997    129192  Tensei Kenja no Isekai Life: Daini no Shokugyo...
# 998    127271                           Ryuu to Sobakasu no Hime
# 999    101571                                 Aggressive Retsuko
#
#                                               genres   type  \
# 0                    Action, Drama, Fantasy, Mystery     TV
# 1    Action, Adventure, Drama, Fantasy, Supernatural     TV
# 2     Mystery, Psychological, Supernatural, Thriller     TV
# 3                        Action, Drama, Supernatural     TV
# 4                          Action, Adventure, Comedy     TV
# ..                                               ...    ...
# 995                           Action, Fantasy, Mecha     TV
# 996                                          Fantasy     TV
# 997               Action, Adventure, Comedy, Fantasy     TV
# 998                    Drama, Music, Mystery, Sci-Fi  MOVIE
# 999                     Comedy, Music, Slice of Life    ONA
#
#      number_of_episodes  rating  total_views  production_cost  \
# 0                    25      84       778095         200000.0
# 1                    26      83       735876         250000.0
# 2                    37      84       708493         100000.0
# 3                    24      85       677899         250000.0
# 4                    13      77       672551         200000.0
# ..                  ...     ...          ...              ...
# 995                  13      67        52265         150000.0
# 996                  12      72        52175         250000.0
# 997                  12      61        52116         300000.0
# 998                   1      73        52055         300000.0
# 999                  10      74        52006         200000.0
#
#      total_box_office  profit_margin
# 0                30.8      -0.999846
# 1                85.0      -0.999660
# 2                30.0      -0.999700
# 3                85.0      -0.999660
# 4                55.0      -0.999725
# ..                ...            ...
# 995              33.0      -0.999780
# 996              35.0      -0.999860
# 997              39.0      -0.999870
# 998              56.0      -0.999813
# 999              23.0      -0.999885
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## **Data Reduction**

# %%
if 'anime_id' in df.columns:
    df.drop("anime_id", axis=1, inplace=True)
else:
    print("Column 'anime_id' not found in the DataFrame.")

df
# Out:
# Column 'anime_id' not found in the DataFrame.
#                                             anime_name  \
# 0                                      Attack on Titan
# 1                                         Demon Slayer
# 2                                           DEATH NOTE
# 3                                       Jujutsu Kaisen
# 4                                     My Hero Academia
# ..                                                 ...
# 995                                    Knights & Magic
# 996                                    Isekai Yakkyoku
# 997  Tensei Kenja no Isekai Life: Daini no Shokugyo...
# 998                           Ryuu to Sobakasu no Hime
# 999                                 Aggressive Retsuko
#
#                                               genres   type  \
# 0                    Action, Drama, Fantasy, Mystery     TV
# 1    Action, Adventure, Drama, Fantasy, Supernatural     TV
# 2     Mystery, Psychological, Supernatural, Thriller     TV
# 3                        Action, Drama, Supernatural     TV
# 4                          Action, Adventure, Comedy     TV
# ..                                               ...    ...
# 995                           Action, Fantasy, Mecha     TV
# 996                                          Fantasy     TV
# 997               Action, Adventure, Comedy, Fantasy     TV
# 998                    Drama, Music, Mystery, Sci-Fi  MOVIE
# 999                     Comedy, Music, Slice of Life    ONA
#
#      number_of_episodes  rating  total_views  production_cost  \
# 0                    25      84       778095         200000.0
# 1                    26      83       735876         250000.0
# 2                    37      84       708493         100000.0
# 3                    24      85       677899         250000.0
# 4                    13      77       672551         200000.0
# ..                  ...     ...          ...              ...
# 995                  13      67        52265         150000.0
# 996                  12      72        52175         250000.0
# 997                  12      61        52116         300000.0
# 998                   1      73        52055         300000.0
# 999                  10      74        52006         200000.0
#
#      total_box_office  profit_margin
# 0                30.8      -0.999846
# 1                85.0      -0.999660
# 2                30.0      -0.999700
# 3                85.0      -0.999660
# 4                55.0      -0.999725
# ..                ...            ...
# 995              33.0      -0.999780
# 996              35.0      -0.999860
# 997              39.0      -0.999870
# 998              56.0      -0.999813
# 999              23.0      -0.999885
#
# [1000 rows x 9 columns]

# %%
df.describe()
# Out:
#        number_of_episodes       rating    total_views  production_cost  \
# count         1000.000000  1000.000000    1000.000000      1000.000000
# mean            19.926000    74.667000  136345.578000    201400.000000
# std             57.600941     7.371733  106097.155245     68649.492007
# min              1.000000    45.000000   52006.000000    100000.000000
# 25%             12.000000    70.000000   69314.000000    150000.000000
# 50%             12.000000    75.000000   97868.500000    200000.000000
# 75%             13.000000    80.000000  158302.250000    250000.000000
# max           1110.000000    91.000000  778095.000000    300000.000000
#
#        total_box_office  profit_margin
# count       1000.000000    1000.000000
# mean          33.262500      -0.999812
# std           15.974517       0.000117
# min            7.000000      -0.999977
# 25%           20.000000      -0.999900
# 50%           33.000000      -0.999836
# 75%           46.000000      -0.999750
# max           85.000000      -0.999410
